# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_07_2_Keras_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 7: Generative Adversarial Networks**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 7 Material
#
# * Part 7.1: Introduction to GANS for Image and Data Generation [[Video]](https://www.youtube.com/watch?v=0QnCH6tlZgc&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_1_gan_intro.ipynb)
# * **Part 7.2: Implementing a GAN in Keras** [[Video]](https://www.youtube.com/watch?v=T-MCludVNn4&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_2_Keras_gan.ipynb)
# * Part 7.3: Face Generation with StyleGAN and Python [[Video]](https://www.youtube.com/watch?v=Wwwyr7cOBlU&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_3_style_gan.ipynb)
# * Part 7.4: GANS for Semi-Supervised Learning in Keras [[Video]](https://www.youtube.com/watch?v=ZPewmEu7644&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_4_gan_semi_supervised.ipynb)
# * Part 7.5: An Overview of GAN Research [[Video]](https://www.youtube.com/watch?v=cvCvZKvlvq4&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](t81_558_class_07_5_gan_research.ipynb)

# %% [markdown]
# # Part 7.2: Implementing DCGANs in Keras
#
# Paper that described the type of DCGAN that we will create in this module.
#
# * Radford, A., Metz, L., & Chintala, S. (2015). [Unsupervised representation learning with deep convolutional generative adversarial networks](https://arxiv.org/abs/1511.06434). *arXiv preprint arXiv:1511.06434*.
#
# This paper implements a DCGAN as follows:
#
# * No pre-processing was applied to training images besides scaling to the range of the tanh activation function [-1, 1].
# * All models were trained with mini-batch stochastic gradient descent (SGD) with a mini-batch size of 128.
# * All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
# * In the LeakyReLU, the slope of the leak was set to 0.2 in all models.
# * we used the Adam optimizer(Kingma & Ba, 2014) with tuned hyperparameters. We found the suggested learning rate of 0.001, to be too high, using 0.0002 instead.
# * Additionally, we found leaving the momentum term $\beta{1}$ at the suggested value of 0.9 resulted in training oscillation and instability while reducing it to 0.5 helped stabilize training.
#
# The paper also provides the following architecture guidelines for stable Deep Convolutional GANs:
#
# * Replace any pooling layers with strided convolutions (discriminator) and fractional-strided convolutions (generator).
# * Use batchnorm in both the generator and the discriminator.
# * Remove fully connected hidden layers for deeper architectures.
# * Use ReLU activation in generator for all layers except for the output, which uses Tanh.
# * Use LeakyReLU activation in the discriminator for all layers.
#
# While creating the material for this module I used a number of Internet resources, some of the most helpful were:
#
# * [Keep Calm and train a GAN. Pitfalls and Tips on training Generative Adversarial Networks](https://medium.com/@utk.is.here/keep-calm-and-train-a-gan-pitfalls-and-tips-on-training-generative-adversarial-networks-edd529764aa9)
# * [Collection of Keras implementations of Generative Adversarial Networks GANs](https://github.com/eriklindernoren/Keras-GAN)
# * [dcgan-facegenerator](https://github.com/platonovsimeon/dcgan-facegenerator), [Semi-Paywalled Article by GitHub Author](https://medium.com/datadriveninvestor/generating-human-faces-with-keras-3ccd54c17f16)
#
# The program created next will generate faces similar to these.  While these faces are not perfect, they demonstrate how we can construct and train a GAN on or own.  Later we will see how to import very advanced weights from nVidia to produce high resolution, realistic looking faces.
#
# ![GAN](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/gan-3.png "GAN")

# %% [markdown]
# The following packages will be used to implement a basic GAN system in Python/Keras.

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = True
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Note: using Google CoLab

# %%
from keras.layers import Input, Reshape, Dropout, Dense, Flatten, BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model, load_model
from keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# I suggest running this code with a GPU, it will be very slow on a CPU alone.  The following code mounts your Google drive for use with Google CoLab.  If you are not using CoLab, the following code will not work.

# %% [markdown]
# These are the constants that define how the GANs will be created for this example.  The higher the resolution, the more memory that will be needed.  Higher resolution will also result in longer run times.  For Google CoLab (with GPU) 128x128 resolution is as high as can be used (due to memoru).  Note that the resolution is specified as a multiple of 32.  So **GENERATE_RES** of 1 is 32, 2 is 64, etc.
#
# To run this you will need training data.  The training data can be any collection of images.  I suggest using training data from the following two locations.  Simply unzip and combine to a common directory.  This directory should be uploaded to Google Drive (if you are using CoLab). The constant **DATA_PATH** defines where these images are stored.
#
# The source data (faces) used in this module can be found here:
#
# * [Kaggle Faces Data New](https://www.kaggle.com/gasgallo/faces-data-new)
# * [Kaggle Lag Dataset: Dataset of faces, from more than 1k different subjects](https://www.kaggle.com/gasgallo/lag-dataset)

# %%
# Generation resolution - Must be square 
# Training data is also scaled to this.
# Note GENERATE_RES higher than 4 will blow Google CoLab's memory.
GENERATE_RES = 2 # (1=32, 2=64, 3=96, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16
SAVE_FREQ = 100

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/My Drive/'
EPOCHS = 50000
BATCH_SIZE = 32

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 64px square images.

# %% [markdown]
# Next we will load and preprocess the images.  This can take awhile.  Google CoLab took around an hour to process.  Because of this we store the processed file as a binary.  This way we can simply reload the processed training data and quickly use it.  It is most efficient to only perform this operation once.  The dimensions of the image are encoded into the filename of the binary file because we need to regenerate it if these change.

# %%
# Image set has 11,682 images.  Can take over an hour for initial preprocessing.
# Because of this time needed, save a Numpy preprocessed file.
# Note, that file is large enough to cause problems for sume verisons of Pickle,
# so Numpy binary files are used.
training_binary_path = os.path.join(DATA_PATH,f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  print("Loading training images...")

  training_data = []
  dreams_path = os.path.join(DATA_PATH,'dreams')
  for filename in tqdm(os.listdir(dreams_path)):
      path = os.path.join(dreams_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data / 127.5 - 1.

  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
else:
  print("Loading previous training binary...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/My Drive/training_data_64_64.npy
# Loading previous training binary...

# %% [markdown]
# The code below creates the generator and discriminator.

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    for i in range(GENERATE_RES):
      model.add(UpSampling2D())
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    input = Input(shape=(seed_size,))
    generated_image = model(input)

    return Model(input,generated_image)


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    input_image = Input(shape=image_shape)

    validity = model(input_image)

    return Model(input_image, validity)
  
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %% [markdown]
# Next we actually build the discriminator and the generator.  Both will be trained with the Adam optimizer.

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)
optimizer = Adam(1.5e-4,0.5) # learning rate and momentum adjusted from paper

discriminator = build_discriminator(image_shape)
discriminator.compile(loss="binary_crossentropy",optimizer=optimizer,metrics=["accuracy"])
generator = build_generator(SEED_SIZE,IMAGE_CHANNELS)

random_input = Input(shape=(SEED_SIZE,))

generated_image = generator(random_input)

discriminator.trainable = False

validity = discriminator(generated_image)

combined = Model(random_input,validity)
combined.compile(loss="binary_crossentropy",optimizer=optimizer,metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.

# %%
y_real = np.ones((BATCH_SIZE,1))
y_fake = np.zeros((BATCH_SIZE,1))

fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, SEED_SIZE))

cnt = 1
for epoch in range(EPOCHS):
    idx = np.random.randint(0,training_data.shape[0],BATCH_SIZE)
    x_real = training_data[idx]

    # Generate some images
    seed = np.random.normal(0,1,(BATCH_SIZE,SEED_SIZE))
    x_fake = generator.predict(seed)

    # Train discriminator on real and fake
    discriminator_metric_real = discriminator.train_on_batch(x_real,y_real)
    discriminator_metric_generated = discriminator.train_on_batch(x_fake,y_fake)
    discriminator_metric = 0.5 * np.add(discriminator_metric_real,discriminator_metric_generated)
    
    # Train generator on Calculate losses
    generator_metric = combined.train_on_batch(seed,y_real)
    
    # Time for an update?
    if epoch % SAVE_FREQ == 0:
        save_images(cnt, fixed_seed)
        cnt += 1
        print(f"Epoch {epoch}, Discriminator accuarcy: {discriminator_metric[1]}, Generator accuracy: {generator_metric[1]}")
        
generator.save(os.path.join(DATA_PATH,"dreamfa_generator.h5"))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 0, Discriminator accuarcy: 0.171875, Generator accuracy: 0.78125
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 100, Discriminator accuarcy: 0.78125, Generator accuracy: 0.0
# Epoch 200, Discriminator accuarcy: 0.96875, Generator accuracy: 0.96875
# Epoch 300, Discriminator accuarcy: 0.9375, Generator accuracy: 1.0
# Epoch 400, Discriminator accuarcy: 0.578125, Generator accuracy: 0.09375
# Epoch 500, Discriminator accuarcy: 0.796875, Generator accuracy: 0.4375
# Epoch 600, Discriminator accuarcy: 0.484375, Generator accuracy: 0.3125
# Epoch 700, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 800, Discriminator accuarcy: 0.546875, Generator accuracy: 0.09375
# Epoch 900, Discriminator accuarcy: 0.734375, Generator accuracy: 0.28125
# Epoch 1000, Discriminator accuarcy: 0.296875, Generator accuracy: 0.21875
# Epoch 1100, Discriminator accuarcy: 0.5625, Generator accuracy: 0.25
# Epoch 1200, Discriminator accuarcy: 0.375, Generator accuracy: 0.21875
# Epoch 1300, Discriminator accuarcy: 0.65625, Generator accuracy: 0.09375
# Epoch 1400, Discriminator accuarcy: 0.671875, Generator accuracy: 0.3125
# Epoch 1500, Discriminator accuarcy: 0.546875, Generator accuracy: 0.125
# Epoch 1600, Discriminator accuarcy: 0.71875, Generator accuracy: 0.15625
# Epoch 1700, Discriminator accuarcy: 0.609375, Generator accuracy: 0.15625
# Epoch 1800, Discriminator accuarcy: 0.65625, Generator accuracy: 0.15625
# Epoch 1900, Discriminator accuarcy: 0.484375, Generator accuracy: 0.03125
# Epoch 2000, Discriminator accuarcy: 0.65625, Generator accuracy: 0.125
# Epoch 2100, Discriminator accuarcy: 0.515625, Generator accuracy: 0.25
# Epoch 2200, Discriminator accuarcy: 0.5625, Generator accuracy: 0.28125
# Epoch 2300, Discriminator accuarcy: 0.625, Generator accuracy: 0.1875
# Epoch 2400, Discriminator accuarcy: 0.390625, Generator accuracy: 0.21875
# Epoch 2500, Discriminator accuarcy: 0.453125, Generator accuracy: 0.21875
# Epoch 2600, Discriminator accuarcy: 0.671875, Generator accuracy: 0.0625
# Epoch 2700, Discriminator accuarcy: 0.65625, Generator accuracy: 0.21875
# Epoch 2800, Discriminator accuarcy: 0.734375, Generator accuracy: 0.125
# Epoch 2900, Discriminator accuarcy: 0.53125, Generator accuracy: 0.15625
# Epoch 3000, Discriminator accuarcy: 0.625, Generator accuracy: 0.1875
# Epoch 3100, Discriminator accuarcy: 0.453125, Generator accuracy: 0.3125
# Epoch 3200, Discriminator accuarcy: 0.78125, Generator accuracy: 0.28125
# Epoch 3300, Discriminator accuarcy: 0.65625, Generator accuracy: 0.21875
# Epoch 3400, Discriminator accuarcy: 0.625, Generator accuracy: 0.21875
# Epoch 3500, Discriminator accuarcy: 0.5625, Generator accuracy: 0.34375
# Epoch 3600, Discriminator accuarcy: 0.578125, Generator accuracy: 0.3125
# Epoch 3700, Discriminator accuarcy: 0.40625, Generator accuracy: 0.09375
# Epoch 3800, Discriminator accuarcy: 0.625, Generator accuracy: 0.53125
# Epoch 3900, Discriminator accuarcy: 0.671875, Generator accuracy: 0.125
# Epoch 4000, Discriminator accuarcy: 0.5625, Generator accuracy: 0.09375
# Epoch 4100, Discriminator accuarcy: 0.71875, Generator accuracy: 0.4375
# Epoch 4200, Discriminator accuarcy: 0.71875, Generator accuracy: 0.1875
# Epoch 4300, Discriminator accuarcy: 0.5625, Generator accuracy: 0.1875
# Epoch 4400, Discriminator accuarcy: 0.8125, Generator accuracy: 0.21875
# Epoch 4500, Discriminator accuarcy: 0.734375, Generator accuracy: 0.1875
# Epoch 4600, Discriminator accuarcy: 0.515625, Generator accuracy: 0.3125
# Epoch 4700, Discriminator accuarcy: 0.609375, Generator accuracy: 0.34375
# Epoch 4800, Discriminator accuarcy: 0.734375, Generator accuracy: 0.25
# Epoch 4900, Discriminator accuarcy: 0.71875, Generator accuracy: 0.15625
# Epoch 5000, Discriminator accuarcy: 0.65625, Generator accuracy: 0.21875
# Epoch 5100, Discriminator accuarcy: 0.65625, Generator accuracy: 0.15625
# Epoch 5200, Discriminator accuarcy: 0.671875, Generator accuracy: 0.1875
# Epoch 5300, Discriminator accuarcy: 0.65625, Generator accuracy: 0.3125
# Epoch 5400, Discriminator accuarcy: 0.71875, Generator accuracy: 0.21875
# Epoch 5500, Discriminator accuarcy: 0.609375, Generator accuracy: 0.28125
# Epoch 5600, Discriminator accuarcy: 0.703125, Generator accuracy: 0.28125
# Epoch 5700, Discriminator accuarcy: 0.796875, Generator accuracy: 0.21875
# Epoch 5800, Discriminator accuarcy: 0.78125, Generator accuracy: 0.15625
# Epoch 5900, Discriminator accuarcy: 0.65625, Generator accuracy: 0.28125
# Epoch 6000, Discriminator accuarcy: 0.59375, Generator accuracy: 0.28125
# Epoch 6100, Discriminator accuarcy: 0.53125, Generator accuracy: 0.21875
# Epoch 6200, Discriminator accuarcy: 0.609375, Generator accuracy: 0.25
# Epoch 6300, Discriminator accuarcy: 0.65625, Generator accuracy: 0.125
# Epoch 6400, Discriminator accuarcy: 0.671875, Generator accuracy: 0.09375
# Epoch 6500, Discriminator accuarcy: 0.71875, Generator accuracy: 0.34375
# Epoch 6600, Discriminator accuarcy: 0.65625, Generator accuracy: 0.4375
# Epoch 6700, Discriminator accuarcy: 0.59375, Generator accuracy: 0.1875
# Epoch 6800, Discriminator accuarcy: 0.578125, Generator accuracy: 0.0625
# Epoch 6900, Discriminator accuarcy: 0.640625, Generator accuracy: 0.1875
# Epoch 7000, Discriminator accuarcy: 0.78125, Generator accuracy: 0.25
# Epoch 7100, Discriminator accuarcy: 0.59375, Generator accuracy: 0.15625
# Epoch 7200, Discriminator accuarcy: 0.84375, Generator accuracy: 0.15625
# Epoch 7300, Discriminator accuarcy: 0.53125, Generator accuracy: 0.25
# Epoch 7400, Discriminator accuarcy: 0.46875, Generator accuracy: 0.15625
# Epoch 7500, Discriminator accuarcy: 0.671875, Generator accuracy: 0.15625
# Epoch 7600, Discriminator accuarcy: 0.453125, Generator accuracy: 0.09375
# Epoch 7700, Discriminator accuarcy: 0.65625, Generator accuracy: 0.25
# Epoch 7800, Discriminator accuarcy: 0.703125, Generator accuracy: 0.03125
# Epoch 7900, Discriminator accuarcy: 0.6875, Generator accuracy: 0.125
# Epoch 8000, Discriminator accuarcy: 0.78125, Generator accuracy: 0.09375
# Epoch 8100, Discriminator accuarcy: 0.484375, Generator accuracy: 0.25
# Epoch 8200, Discriminator accuarcy: 0.71875, Generator accuracy: 0.09375
# Epoch 8300, Discriminator accuarcy: 0.671875, Generator accuracy: 0.09375
# Epoch 8400, Discriminator accuarcy: 0.71875, Generator accuracy: 0.15625
# Epoch 8500, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 8600, Discriminator accuarcy: 0.765625, Generator accuracy: 0.1875
# Epoch 8700, Discriminator accuarcy: 0.75, Generator accuracy: 0.28125
# Epoch 8800, Discriminator accuarcy: 0.609375, Generator accuracy: 0.15625
# Epoch 8900, Discriminator accuarcy: 0.546875, Generator accuracy: 0.21875
# Epoch 9000, Discriminator accuarcy: 0.78125, Generator accuracy: 0.125
# Epoch 9100, Discriminator accuarcy: 0.734375, Generator accuracy: 0.125
# Epoch 9200, Discriminator accuarcy: 0.75, Generator accuracy: 0.1875
# Epoch 9300, Discriminator accuarcy: 0.78125, Generator accuracy: 0.1875
# Epoch 9400, Discriminator accuarcy: 0.71875, Generator accuracy: 0.03125
# Epoch 9500, Discriminator accuarcy: 0.65625, Generator accuracy: 0.09375
# Epoch 9600, Discriminator accuarcy: 0.609375, Generator accuracy: 0.34375
# Epoch 9700, Discriminator accuarcy: 0.734375, Generator accuracy: 0.09375
# Epoch 9800, Discriminator accuarcy: 0.671875, Generator accuracy: 0.03125
# Epoch 9900, Discriminator accuarcy: 0.625, Generator accuracy: 0.15625
# Epoch 10000, Discriminator accuarcy: 0.796875, Generator accuracy: 0.15625
# Epoch 10100, Discriminator accuarcy: 0.578125, Generator accuracy: 0.21875
# Epoch 10200, Discriminator accuarcy: 0.796875, Generator accuracy: 0.28125
# Epoch 10300, Discriminator accuarcy: 0.6875, Generator accuracy: 0.4375
# Epoch 10400, Discriminator accuarcy: 0.78125, Generator accuracy: 0.25
# Epoch 10500, Discriminator accuarcy: 0.71875, Generator accuracy: 0.0625
# Epoch 10600, Discriminator accuarcy: 0.71875, Generator accuracy: 0.15625
# Epoch 10700, Discriminator accuarcy: 0.546875, Generator accuracy: 0.3125
# Epoch 10800, Discriminator accuarcy: 0.703125, Generator accuracy: 0.09375
# Epoch 10900, Discriminator accuarcy: 0.625, Generator accuracy: 0.0625
# Epoch 11000, Discriminator accuarcy: 0.703125, Generator accuracy: 0.15625
# Epoch 11100, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0625
# Epoch 11200, Discriminator accuarcy: 0.65625, Generator accuracy: 0.15625
# Epoch 11300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.125
# Epoch 11400, Discriminator accuarcy: 0.875, Generator accuracy: 0.15625
# Epoch 11500, Discriminator accuarcy: 0.703125, Generator accuracy: 0.03125
# Epoch 11600, Discriminator accuarcy: 0.703125, Generator accuracy: 0.1875
# Epoch 11700, Discriminator accuarcy: 0.65625, Generator accuracy: 0.09375
# Epoch 11800, Discriminator accuarcy: 0.75, Generator accuracy: 0.125
# Epoch 11900, Discriminator accuarcy: 0.640625, Generator accuracy: 0.15625
# Epoch 12000, Discriminator accuarcy: 0.78125, Generator accuracy: 0.09375
# Epoch 12100, Discriminator accuarcy: 0.8125, Generator accuracy: 0.375
# Epoch 12200, Discriminator accuarcy: 0.75, Generator accuracy: 0.3125
# Epoch 12300, Discriminator accuarcy: 0.765625, Generator accuracy: 0.1875
# Epoch 12400, Discriminator accuarcy: 0.546875, Generator accuracy: 0.125
# Epoch 12500, Discriminator accuarcy: 0.8125, Generator accuracy: 0.15625
# Epoch 12600, Discriminator accuarcy: 0.75, Generator accuracy: 0.21875
# Epoch 12700, Discriminator accuarcy: 0.859375, Generator accuracy: 0.09375
# Epoch 12800, Discriminator accuarcy: 0.765625, Generator accuracy: 0.25
# Epoch 12900, Discriminator accuarcy: 0.78125, Generator accuracy: 0.0625
# Epoch 13000, Discriminator accuarcy: 0.703125, Generator accuracy: 0.21875
# Epoch 13100, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 13200, Discriminator accuarcy: 0.65625, Generator accuracy: 0.09375
# Epoch 13300, Discriminator accuarcy: 0.515625, Generator accuracy: 0.15625
# Epoch 13400, Discriminator accuarcy: 0.828125, Generator accuracy: 0.15625
# Epoch 13500, Discriminator accuarcy: 0.609375, Generator accuracy: 0.25
# Epoch 13600, Discriminator accuarcy: 0.703125, Generator accuracy: 0.0625
# Epoch 13700, Discriminator accuarcy: 0.75, Generator accuracy: 0.125
# Epoch 13800, Discriminator accuarcy: 0.703125, Generator accuracy: 0.0625
# Epoch 13900, Discriminator accuarcy: 0.796875, Generator accuracy: 0.34375
# Epoch 14000, Discriminator accuarcy: 0.796875, Generator accuracy: 0.125
# Epoch 14100, Discriminator accuarcy: 0.640625, Generator accuracy: 0.28125
# Epoch 14200, Discriminator accuarcy: 0.75, Generator accuracy: 0.03125
# Epoch 14300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.21875
# Epoch 14400, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 14500, Discriminator accuarcy: 0.75, Generator accuracy: 0.09375
# Epoch 14600, Discriminator accuarcy: 0.78125, Generator accuracy: 0.09375
# Epoch 14700, Discriminator accuarcy: 0.609375, Generator accuracy: 0.09375
# Epoch 14800, Discriminator accuarcy: 0.8125, Generator accuracy: 0.09375
# Epoch 14900, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 15000, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0
# Epoch 15100, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 15200, Discriminator accuarcy: 0.8125, Generator accuracy: 0.03125
# Epoch 15300, Discriminator accuarcy: 0.609375, Generator accuracy: 0.1875
# Epoch 15400, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 15500, Discriminator accuarcy: 0.6875, Generator accuracy: 0.0625
# Epoch 15600, Discriminator accuarcy: 0.78125, Generator accuracy: 0.125
# Epoch 15700, Discriminator accuarcy: 0.75, Generator accuracy: 0.1875
# Epoch 15800, Discriminator accuarcy: 0.765625, Generator accuracy: 0.3125
# Epoch 15900, Discriminator accuarcy: 0.78125, Generator accuracy: 0.1875
# Epoch 16000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 16100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.40625
# Epoch 16200, Discriminator accuarcy: 0.71875, Generator accuracy: 0.1875
# Epoch 16300, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0
# Epoch 16400, Discriminator accuarcy: 0.671875, Generator accuracy: 0.09375
# Epoch 16500, Discriminator accuarcy: 0.84375, Generator accuracy: 0.21875
# Epoch 16600, Discriminator accuarcy: 0.953125, Generator accuracy: 0.125
# Epoch 16700, Discriminator accuarcy: 0.703125, Generator accuracy: 0.15625
# Epoch 16800, Discriminator accuarcy: 0.921875, Generator accuracy: 0.1875
# Epoch 16900, Discriminator accuarcy: 0.78125, Generator accuracy: 0.28125
# Epoch 17000, Discriminator accuarcy: 0.890625, Generator accuracy: 0.28125
# Epoch 17100, Discriminator accuarcy: 0.796875, Generator accuracy: 0.03125
# Epoch 17200, Discriminator accuarcy: 0.875, Generator accuracy: 0.09375
# Epoch 17300, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 17400, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 17500, Discriminator accuarcy: 0.78125, Generator accuracy: 0.21875
# Epoch 17600, Discriminator accuarcy: 0.828125, Generator accuracy: 0.1875
# Epoch 17700, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0625
# Epoch 17800, Discriminator accuarcy: 0.84375, Generator accuracy: 0.125
# Epoch 17900, Discriminator accuarcy: 0.671875, Generator accuracy: 0.15625
# Epoch 18000, Discriminator accuarcy: 0.734375, Generator accuracy: 0.1875
# Epoch 18100, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0625
# Epoch 18200, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0625
# Epoch 18300, Discriminator accuarcy: 0.84375, Generator accuracy: 0.125
# Epoch 18400, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0625
# Epoch 18500, Discriminator accuarcy: 0.765625, Generator accuracy: 0.09375
# Epoch 18600, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0625
# Epoch 18700, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0625
# Epoch 18800, Discriminator accuarcy: 0.703125, Generator accuracy: 0.03125
# Epoch 18900, Discriminator accuarcy: 0.75, Generator accuracy: 0.09375
# Epoch 19000, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 19100, Discriminator accuarcy: 0.796875, Generator accuracy: 0.1875
# Epoch 19200, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 19300, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 19400, Discriminator accuarcy: 0.890625, Generator accuracy: 0.15625
# Epoch 19500, Discriminator accuarcy: 0.78125, Generator accuracy: 0.1875
# Epoch 19600, Discriminator accuarcy: 0.9375, Generator accuracy: 0.15625
# Epoch 19700, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0
# Epoch 19800, Discriminator accuarcy: 0.8125, Generator accuracy: 0.21875
# Epoch 19900, Discriminator accuarcy: 0.734375, Generator accuracy: 0.15625
# Epoch 20000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.03125
# Epoch 20100, Discriminator accuarcy: 0.71875, Generator accuracy: 0.0625
# Epoch 20200, Discriminator accuarcy: 0.71875, Generator accuracy: 0.0
# Epoch 20300, Discriminator accuarcy: 0.78125, Generator accuracy: 0.03125
# Epoch 20400, Discriminator accuarcy: 0.796875, Generator accuracy: 0.21875
# Epoch 20500, Discriminator accuarcy: 0.875, Generator accuracy: 0.09375
# Epoch 20600, Discriminator accuarcy: 0.875, Generator accuracy: 0.25
# Epoch 20700, Discriminator accuarcy: 0.71875, Generator accuracy: 0.1875
# Epoch 20800, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0
# Epoch 20900, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 21000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.21875
# Epoch 21100, Discriminator accuarcy: 0.78125, Generator accuracy: 0.09375
# Epoch 21200, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 21300, Discriminator accuarcy: 0.75, Generator accuracy: 0.125
# Epoch 21400, Discriminator accuarcy: 0.828125, Generator accuracy: 0.25
# Epoch 21500, Discriminator accuarcy: 0.765625, Generator accuracy: 0.09375
# Epoch 21600, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 21700, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 21800, Discriminator accuarcy: 0.84375, Generator accuracy: 0.03125
# Epoch 21900, Discriminator accuarcy: 0.8125, Generator accuracy: 0.21875
# Epoch 22000, Discriminator accuarcy: 0.71875, Generator accuracy: 0.09375
# Epoch 22100, Discriminator accuarcy: 0.703125, Generator accuracy: 0.0625
# Epoch 22200, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 22300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 22400, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0625
# Epoch 22500, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 22600, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 22700, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0
# Epoch 22800, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 22900, Discriminator accuarcy: 0.828125, Generator accuracy: 0.125
# Epoch 23000, Discriminator accuarcy: 0.859375, Generator accuracy: 0.125
# Epoch 23100, Discriminator accuarcy: 0.8125, Generator accuracy: 0.03125
# Epoch 23200, Discriminator accuarcy: 0.8125, Generator accuracy: 0.1875
# Epoch 23300, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 23400, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0625
# Epoch 23500, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0
# Epoch 23600, Discriminator accuarcy: 0.796875, Generator accuracy: 0.03125
# Epoch 23700, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
# Epoch 23800, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
# Epoch 23900, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 24000, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 24100, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0625
# Epoch 24200, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0
# Epoch 24300, Discriminator accuarcy: 0.8125, Generator accuracy: 0.03125
# Epoch 24400, Discriminator accuarcy: 0.921875, Generator accuracy: 0.03125
# Epoch 24500, Discriminator accuarcy: 0.8125, Generator accuracy: 0.09375
# Epoch 24600, Discriminator accuarcy: 0.875, Generator accuracy: 0.09375
# Epoch 24700, Discriminator accuarcy: 0.734375, Generator accuracy: 0.125
# Epoch 24800, Discriminator accuarcy: 0.796875, Generator accuracy: 0.21875
# Epoch 24900, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 25000, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0625
# Epoch 25100, Discriminator accuarcy: 0.78125, Generator accuracy: 0.0625
# Epoch 25200, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 25300, Discriminator accuarcy: 0.71875, Generator accuracy: 0.125
# Epoch 25400, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 25500, Discriminator accuarcy: 0.640625, Generator accuracy: 0.0
# Epoch 25600, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 25700, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 25800, Discriminator accuarcy: 0.90625, Generator accuracy: 0.09375
# Epoch 25900, Discriminator accuarcy: 0.9375, Generator accuracy: 0.09375
# Epoch 26000, Discriminator accuarcy: 0.796875, Generator accuracy: 0.1875
# Epoch 26100, Discriminator accuarcy: 0.875, Generator accuracy: 0.0
# Epoch 26200, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 26300, Discriminator accuarcy: 0.875, Generator accuracy: 0.1875
# Epoch 26400, Discriminator accuarcy: 0.875, Generator accuracy: 0.09375
# Epoch 26500, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0
# Epoch 26600, Discriminator accuarcy: 0.765625, Generator accuracy: 0.03125
# Epoch 26700, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 26800, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0
# Epoch 26900, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 27000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.1875
# Epoch 27100, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 27200, Discriminator accuarcy: 0.859375, Generator accuracy: 0.125
# Epoch 27300, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0625
# Epoch 27400, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 27500, Discriminator accuarcy: 0.953125, Generator accuracy: 0.0625
# Epoch 27600, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 27700, Discriminator accuarcy: 0.734375, Generator accuracy: 0.09375
# Epoch 27800, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0625
# Epoch 27900, Discriminator accuarcy: 0.90625, Generator accuracy: 0.09375
# Epoch 28000, Discriminator accuarcy: 0.859375, Generator accuracy: 0.28125
# Epoch 28100, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 28200, Discriminator accuarcy: 0.875, Generator accuracy: 0.15625
# Epoch 28300, Discriminator accuarcy: 0.75, Generator accuracy: 0.09375
# Epoch 28400, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 28500, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 28600, Discriminator accuarcy: 0.90625, Generator accuracy: 0.15625
# Epoch 28700, Discriminator accuarcy: 0.8125, Generator accuracy: 0.125
# Epoch 28800, Discriminator accuarcy: 0.78125, Generator accuracy: 0.1875
# Epoch 28900, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 29000, Discriminator accuarcy: 0.765625, Generator accuracy: 0.0625
# Epoch 29100, Discriminator accuarcy: 0.796875, Generator accuracy: 0.03125
# Epoch 29200, Discriminator accuarcy: 0.734375, Generator accuracy: 0.0
# Epoch 29300, Discriminator accuarcy: 0.921875, Generator accuracy: 0.03125
# Epoch 29400, Discriminator accuarcy: 0.921875, Generator accuracy: 0.15625
# Epoch 29500, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0625
# Epoch 29600, Discriminator accuarcy: 0.8125, Generator accuracy: 0.03125
# Epoch 29700, Discriminator accuarcy: 0.859375, Generator accuracy: 0.125
# Epoch 29800, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 29900, Discriminator accuarcy: 0.703125, Generator accuracy: 0.0
# Epoch 30000, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 30100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.15625
# Epoch 30200, Discriminator accuarcy: 0.84375, Generator accuracy: 0.09375
# Epoch 30300, Discriminator accuarcy: 0.78125, Generator accuracy: 0.09375
# Epoch 30400, Discriminator accuarcy: 0.875, Generator accuracy: 0.03125
# Epoch 30500, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 30600, Discriminator accuarcy: 0.796875, Generator accuracy: 0.1875
# Epoch 30700, Discriminator accuarcy: 0.8125, Generator accuracy: 0.125
# Epoch 30800, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 30900, Discriminator accuarcy: 0.953125, Generator accuracy: 0.03125
# Epoch 31000, Discriminator accuarcy: 0.8125, Generator accuracy: 0.03125
# Epoch 31100, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 31200, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 31300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 31400, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 31500, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 31600, Discriminator accuarcy: 0.765625, Generator accuracy: 0.15625
# Epoch 31700, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 31800, Discriminator accuarcy: 0.9375, Generator accuracy: 0.1875
# Epoch 31900, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0
# Epoch 32000, Discriminator accuarcy: 0.71875, Generator accuracy: 0.03125
# Epoch 32100, Discriminator accuarcy: 0.8125, Generator accuracy: 0.3125
# Epoch 32200, Discriminator accuarcy: 0.9375, Generator accuracy: 0.1875
# Epoch 32300, Discriminator accuarcy: 0.921875, Generator accuracy: 0.125
# Epoch 32400, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 32500, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0
# Epoch 32600, Discriminator accuarcy: 0.875, Generator accuracy: 0.15625
# Epoch 32700, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0
# Epoch 32800, Discriminator accuarcy: 0.875, Generator accuracy: 0.03125
# Epoch 32900, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 33000, Discriminator accuarcy: 0.875, Generator accuracy: 0.03125
# Epoch 33100, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 33200, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0
# Epoch 33300, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
# Epoch 33400, Discriminator accuarcy: 0.875, Generator accuracy: 0.0625
# Epoch 33500, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0625
# Epoch 33600, Discriminator accuarcy: 0.96875, Generator accuracy: 0.03125
# Epoch 33700, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 33800, Discriminator accuarcy: 0.9375, Generator accuracy: 0.1875
# Epoch 33900, Discriminator accuarcy: 0.75, Generator accuracy: 0.0
# Epoch 34000, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 34100, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0625
# Epoch 34200, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0
# Epoch 34300, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0625
# Epoch 34400, Discriminator accuarcy: 0.796875, Generator accuracy: 0.09375
# Epoch 34500, Discriminator accuarcy: 0.734375, Generator accuracy: 0.3125
# Epoch 34600, Discriminator accuarcy: 0.84375, Generator accuracy: 0.125
# Epoch 34700, Discriminator accuarcy: 0.875, Generator accuracy: 0.125
# Epoch 34800, Discriminator accuarcy: 0.859375, Generator accuracy: 0.09375
# Epoch 34900, Discriminator accuarcy: 0.84375, Generator accuracy: 0.03125
# Epoch 35000, Discriminator accuarcy: 0.828125, Generator accuracy: 0.15625
# Epoch 35100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 35200, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 35300, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 35400, Discriminator accuarcy: 0.890625, Generator accuracy: 0.15625
# Epoch 35500, Discriminator accuarcy: 0.96875, Generator accuracy: 0.125
# Epoch 35600, Discriminator accuarcy: 0.8125, Generator accuracy: 0.0
# Epoch 35700, Discriminator accuarcy: 0.875, Generator accuracy: 0.09375
# Epoch 35800, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 35900, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0
# Epoch 36000, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 36100, Discriminator accuarcy: 0.921875, Generator accuracy: 0.125
# Epoch 36200, Discriminator accuarcy: 0.828125, Generator accuracy: 0.15625
# Epoch 36300, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0
# Epoch 36400, Discriminator accuarcy: 0.828125, Generator accuracy: 0.03125
# Epoch 36500, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 36600, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 36700, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
# Epoch 36800, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 36900, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 37000, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 37100, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 37200, Discriminator accuarcy: 0.875, Generator accuracy: 0.15625
# Epoch 37300, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0
# Epoch 37400, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0625
# Epoch 37500, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 37600, Discriminator accuarcy: 0.875, Generator accuracy: 0.03125
# Epoch 37700, Discriminator accuarcy: 0.921875, Generator accuracy: 0.125
# Epoch 37800, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0
# Epoch 37900, Discriminator accuarcy: 0.859375, Generator accuracy: 0.0625
# Epoch 38000, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0
# Epoch 38100, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0625
# Epoch 38200, Discriminator accuarcy: 0.953125, Generator accuracy: 0.03125
# Epoch 38300, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0
# Epoch 38400, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0
# Epoch 38500, Discriminator accuarcy: 0.796875, Generator accuracy: 0.15625
# Epoch 38600, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0
# Epoch 38700, Discriminator accuarcy: 0.9375, Generator accuracy: 0.21875
# Epoch 38800, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0
# Epoch 38900, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 39000, Discriminator accuarcy: 0.875, Generator accuracy: 0.03125
# Epoch 39100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.03125
# Epoch 39200, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 39300, Discriminator accuarcy: 0.765625, Generator accuracy: 0.125
# Epoch 39400, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0
# Epoch 39500, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 39600, Discriminator accuarcy: 0.9375, Generator accuracy: 0.09375
# Epoch 39700, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0
# Epoch 39800, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0625
# Epoch 39900, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 40000, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 40100, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 40200, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0
# Epoch 40300, Discriminator accuarcy: 0.765625, Generator accuracy: 0.09375
# Epoch 40400, Discriminator accuarcy: 0.96875, Generator accuracy: 0.03125
# Epoch 40500, Discriminator accuarcy: 0.796875, Generator accuracy: 0.125
# Epoch 40600, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0
# Epoch 40700, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0
# Epoch 40800, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0
# Epoch 40900, Discriminator accuarcy: 0.9375, Generator accuracy: 0.03125
# Epoch 41000, Discriminator accuarcy: 0.953125, Generator accuracy: 0.0625
# Epoch 41100, Discriminator accuarcy: 0.921875, Generator accuracy: 0.03125
# Epoch 41200, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 41300, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 41400, Discriminator accuarcy: 0.90625, Generator accuracy: 0.09375
# Epoch 41500, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 41600, Discriminator accuarcy: 0.984375, Generator accuracy: 0.03125
# Epoch 41700, Discriminator accuarcy: 0.96875, Generator accuracy: 0.03125
# Epoch 41800, Discriminator accuarcy: 0.84375, Generator accuracy: 0.03125
# Epoch 41900, Discriminator accuarcy: 0.953125, Generator accuracy: 0.0625
# Epoch 42000, Discriminator accuarcy: 0.859375, Generator accuracy: 0.09375
# Epoch 42100, Discriminator accuarcy: 0.953125, Generator accuracy: 0.03125
# Epoch 42200, Discriminator accuarcy: 0.90625, Generator accuracy: 0.15625
# Epoch 42300, Discriminator accuarcy: 0.953125, Generator accuracy: 0.0
# Epoch 42400, Discriminator accuarcy: 0.765625, Generator accuracy: 0.09375
# Epoch 42500, Discriminator accuarcy: 0.90625, Generator accuracy: 0.125
# Epoch 42600, Discriminator accuarcy: 0.9375, Generator accuracy: 0.09375
# Epoch 42700, Discriminator accuarcy: 0.921875, Generator accuracy: 0.03125
# Epoch 42800, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 42900, Discriminator accuarcy: 0.921875, Generator accuracy: 0.15625
# Epoch 43000, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 43100, Discriminator accuarcy: 0.921875, Generator accuracy: 0.03125
# Epoch 43200, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 43300, Discriminator accuarcy: 0.953125, Generator accuracy: 0.0
# Epoch 43400, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0625
# Epoch 43500, Discriminator accuarcy: 0.953125, Generator accuracy: 0.03125
# Epoch 43600, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 43700, Discriminator accuarcy: 0.75, Generator accuracy: 0.0625
# Epoch 43800, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 43900, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 44000, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0
# Epoch 44100, Discriminator accuarcy: 0.9375, Generator accuracy: 0.15625
# Epoch 44200, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0625
# Epoch 44300, Discriminator accuarcy: 0.84375, Generator accuracy: 0.03125
# Epoch 44400, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0
# Epoch 44500, Discriminator accuarcy: 0.84375, Generator accuracy: 0.15625
# Epoch 44600, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 44700, Discriminator accuarcy: 0.75, Generator accuracy: 0.03125
# Epoch 44800, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0625
# Epoch 44900, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0625
# Epoch 45000, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0625
# Epoch 45100, Discriminator accuarcy: 0.828125, Generator accuracy: 0.25
# Epoch 45200, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 45300, Discriminator accuarcy: 0.859375, Generator accuracy: 0.03125
# Epoch 45400, Discriminator accuarcy: 0.96875, Generator accuracy: 0.03125
# Epoch 45500, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0625
# Epoch 45600, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0625
# Epoch 45700, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0
# Epoch 45800, Discriminator accuarcy: 0.9375, Generator accuracy: 0.125
# Epoch 45900, Discriminator accuarcy: 0.953125, Generator accuracy: 0.09375
# Epoch 46000, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0
# Epoch 46100, Discriminator accuarcy: 0.84375, Generator accuracy: 0.0
# Epoch 46200, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 46300, Discriminator accuarcy: 0.828125, Generator accuracy: 0.0625
# Epoch 46400, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0
# Epoch 46500, Discriminator accuarcy: 0.828125, Generator accuracy: 0.09375
# Epoch 46600, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0
# Epoch 46700, Discriminator accuarcy: 0.8125, Generator accuracy: 0.03125
# Epoch 46800, Discriminator accuarcy: 0.984375, Generator accuracy: 0.03125
# Epoch 46900, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0625
# Epoch 47000, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0625
# Epoch 47100, Discriminator accuarcy: 0.796875, Generator accuracy: 0.0625
# Epoch 47200, Discriminator accuarcy: 0.578125, Generator accuracy: 0.0
# Epoch 47300, Discriminator accuarcy: 0.875, Generator accuracy: 0.15625
# Epoch 47400, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 47500, Discriminator accuarcy: 0.90625, Generator accuracy: 0.03125
# Epoch 47600, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 47700, Discriminator accuarcy: 0.90625, Generator accuracy: 0.0625
# Epoch 47800, Discriminator accuarcy: 0.890625, Generator accuracy: 0.09375
# Epoch 47900, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0625
# Epoch 48000, Discriminator accuarcy: 0.9375, Generator accuracy: 0.1875
# Epoch 48100, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0625
# Epoch 48200, Discriminator accuarcy: 0.984375, Generator accuracy: 0.125
# Epoch 48300, Discriminator accuarcy: 0.953125, Generator accuracy: 0.03125
# Epoch 48400, Discriminator accuarcy: 0.96875, Generator accuracy: 0.03125
# Epoch 48500, Discriminator accuarcy: 0.953125, Generator accuracy: 0.0
# Epoch 48600, Discriminator accuarcy: 0.9375, Generator accuracy: 0.03125
# Epoch 48700, Discriminator accuarcy: 0.890625, Generator accuracy: 0.125
# Epoch 48800, Discriminator accuarcy: 0.96875, Generator accuracy: 0.03125
# Epoch 48900, Discriminator accuarcy: 0.796875, Generator accuracy: 0.125
# Epoch 49000, Discriminator accuarcy: 1.0, Generator accuracy: 0.0
# Epoch 49100, Discriminator accuarcy: 0.921875, Generator accuracy: 0.09375
# Epoch 49200, Discriminator accuarcy: 0.890625, Generator accuracy: 0.03125
# Epoch 49300, Discriminator accuarcy: 1.0, Generator accuracy: 0.0
# Epoch 49400, Discriminator accuarcy: 0.921875, Generator accuracy: 0.125
# Epoch 49500, Discriminator accuarcy: 0.921875, Generator accuracy: 0.0625
# Epoch 49600, Discriminator accuarcy: 0.890625, Generator accuracy: 0.0
# Epoch 49700, Discriminator accuarcy: 0.9375, Generator accuracy: 0.0625
# Epoch 49800, Discriminator accuarcy: 0.96875, Generator accuracy: 0.0625
# Epoch 49900, Discriminator accuarcy: 0.96875, Generator accuracy: 0.1875
